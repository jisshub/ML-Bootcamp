# %% [markdown]
# # 911 Calls Capstone Project

# %% [markdown]
# For this capstone project we will be analyzing some 911 call data from [Kaggle](https://www.kaggle.com/mchirico/montcoalert). The data contains the following fields:
#
# * lat : String variable, Latitude
# * lng: String variable, Longitude
# * desc: String variable, Description of the Emergency Call
# * zip: String variable, Zipcode
# * title: String variable, Title
# * timeStamp: String variable, YYYY-MM-DD HH:MM:SS
# * twp: String variable, Township
# * addr: String variable, Address
# * e: String variable, Dummy variable (always 1)
#
# Just go along with this notebook and try to complete the instructions or answer the questions in bold using your Python and Data Science skills!

# %% [markdown]
# ## Data and Setup

# %% [markdown]
# ____
# ** Import numpy and pandas **

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ** Import visualization libraries and set %matplotlib inline. **

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ** Read in the csv file as a dataframe called df **

# %%
df=pd.read_csv('Datasets/911.csv')

# %% [markdown]
# ** Check the info() of the df **

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423909 entries, 0 to 423908
# Data columns (total 9 columns):
# lat          423909 non-null float64
# lng          423909 non-null float64
# desc         423909 non-null object
# zip          371780 non-null float64
# title        423909 non-null object
# timeStamp    423909 non-null object
# twp          423750 non-null object
# addr         423909 non-null object
# e            423909 non-null int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 29.1+ MB

# %% [markdown]
# ** Check the head of df **

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
#                          addr  e
# 0      REINDEER CT & DEAD END  1
# 1  BRIAR PATH & WHITEMARSH LN  1
# 2                    HAWS AVE  1
# 3          AIRY ST & SWEDE ST  1
# 4    CHERRYWOOD CT & DEAD END  1

# %% [markdown]
# ## Basic Questions

# %% [markdown]
# ** What are the top 5 zipcodes for 911 calls? **

# %%
topzip=df['zip'].value_counts()
topzip.head()
# Out:
# 19401.0    28656
# 19464.0    27948
# 19403.0    21631
# 19446.0    20496
# 19406.0    14097
# Name: zip, dtype: int64

# %% [markdown]
# ** What are the top 5 townships (twp) for 911 calls? **

# %%
toptowns=df['twp'].value_counts()
toptowns.head()
# Out:
# LOWER MERION    36441
# ABINGTON        25835
# NORRISTOWN      23883
# UPPER MERION    22694
# CHELTENHAM      19629
# Name: twp, dtype: int64

# %% [markdown]
# ** Take a look at the 'title' column, how many unique title codes are there? **

# %%
df['title'].unique()
# Out:
# array(['EMS: BACK PAINS/INJURY', 'EMS: DIABETIC EMERGENCY',
#        'Fire: GAS-ODOR/LEAK', 'EMS: CARDIAC EMERGENCY', 'EMS: DIZZINESS',
#        'EMS: HEAD INJURY', 'EMS: NAUSEA/VOMITING',
#        'EMS: RESPIRATORY EMERGENCY', 'EMS: SYNCOPAL EPISODE',
#        'Traffic: VEHICLE ACCIDENT -', 'EMS: VEHICLE ACCIDENT',
#        'Traffic: DISABLED VEHICLE -', 'Fire: APPLIANCE FIRE',
#        'EMS: GENERAL WEAKNESS', 'Fire: CARBON MONOXIDE DETECTOR',
#        'EMS: UNKNOWN MEDICAL EMERGENCY', 'EMS: UNRESPONSIVE SUBJECT',
#        'Fire: VEHICLE ACCIDENT', 'EMS: ALTERED MENTAL STATUS',
#        'Fire: FIRE ALARM', 'EMS: CVA/STROKE',
#        'Traffic: ROAD OBSTRUCTION -', 'EMS: SUBJECT IN PAIN',
#        'EMS: HEMORRHAGING', 'EMS: FALL VICTIM', 'EMS: ASSAULT VICTIM',
#        'EMS: SEIZURES', 'EMS: MEDICAL ALERT ALARM',
#        'EMS: ABDOMINAL PAINS', 'Fire: PUMP DETAIL',
#        'Fire: FIRE INVESTIGATION', 'EMS: OVERDOSE', 'EMS: MATERNITY',
#        'EMS: UNCONSCIOUS SUBJECT', 'EMS: CHOKING', 'EMS: LACERATIONS',
#        'Fire: TRASH/DUMPSTER FIRE', 'Fire: UNKNOWN TYPE FIRE',
#        'Fire: BUILDING FIRE', 'Fire: ELECTRICAL FIRE OUTSIDE',
#        'Fire: DEBRIS/FLUIDS ON HIGHWAY',
#        'Traffic: DEBRIS/FLUIDS ON HIGHWAY -', 'EMS: FEVER',
#        'EMS: ALLERGIC REACTION', 'Traffic: VEHICLE LEAKING FUEL -',
#        'EMS: FRACTURE', 'Fire: BURN VICTIM', 'EMS: BURN VICTIM',
#        'Fire: RESCUE - GENERAL', 'Fire: WOODS/FIELD FIRE',
#        'EMS: RESCUE - GENERAL', 'Fire: FIRE SPECIAL SERVICE',
#        'Fire: VEHICLE FIRE', 'Traffic: VEHICLE FIRE -',
#        'EMS: WARRANT SERVICE', 'Fire: S/B AT HELICOPTER LANDING',
#        'EMS: EMS SPECIAL SERVICE', 'Traffic: HAZARDOUS ROAD CONDITIONS -',
#        'Fire: RESCUE - ELEVATOR', 'EMS: FIRE SPECIAL SERVICE',
#        'EMS: DEHYDRATION', 'EMS: CARBON MONOXIDE DETECTOR',
#        'EMS: BUILDING FIRE', 'EMS: APPLIANCE FIRE', 'EMS: SHOOTING',
#        'EMS: POISONING', 'Fire: TRANSFERRED CALL',
#        'Fire: RESCUE - TECHNICAL', 'EMS: RESCUE - TECHNICAL',
#        'Fire: VEHICLE LEAKING FUEL', 'EMS: EYE INJURY',
#        'EMS: ELECTROCUTION', 'EMS: STABBING', 'Fire: FIRE POLICE NEEDED',
#        'EMS: AMPUTATION', 'EMS: ANIMAL BITE', 'EMS: FIRE ALARM',
#        'EMS: VEHICLE FIRE', 'EMS: HAZARDOUS MATERIALS INCIDENT',
#        'EMS: RESCUE - ELEVATOR', 'EMS: FIRE INVESTIGATION',
#        'Fire: MEDICAL ALERT ALARM', 'EMS: UNKNOWN TYPE FIRE',
#        'EMS: GAS-ODOR/LEAK', 'Fire: TRAIN CRASH',
#        'Fire: HAZARDOUS MATERIALS INCIDENT', 'EMS: TRANSFERRED CALL',
#        'EMS: TRAIN CRASH', 'EMS: RESCUE - WATER',
#        'EMS: S/B AT HELICOPTER LANDING',
#        'Fire: UNKNOWN MEDICAL EMERGENCY', 'Fire: RESCUE - WATER',
#        'EMS: CARDIAC ARREST', 'EMS: PLANE CRASH', 'Fire: PLANE CRASH',
#        'EMS: WOODS/FIELD FIRE', 'Fire: CARDIAC ARREST',
#        'Fire: EMS SPECIAL SERVICE', 'Fire: UNCONSCIOUS SUBJECT',
#        'EMS: HEAT EXHAUSTION', 'EMS: DEBRIS/FLUIDS ON HIGHWAY',
#        'EMS: ACTIVE SHOOTER', 'EMS: DISABLED VEHICLE',
#        'Fire: POLICE INFORMATION', 'Fire: DIABETIC EMERGENCY',
#        'EMS: BOMB DEVICE FOUND', 'Fire: SYNCOPAL EPISODE',
#        'EMS: INDUSTRIAL ACCIDENT', 'EMS: DROWNING', 'EMS: SUSPICIOUS',
#        'Fire: FALL VICTIM', 'EMS: ARMED SUBJECT',
#        'Fire: CARDIAC EMERGENCY', 'EMS: STANDBY FOR ANOTHER CO',
#        'EMS: ELECTRICAL FIRE OUTSIDE', 'Fire: UNRESPONSIVE SUBJECT',
#        'EMS: HIT + RUN', 'EMS: SUICIDE THREAT', 'Fire: DISABLED VEHICLE',
#        'Fire: ANIMAL COMPLAINT', 'Fire: STANDBY FOR ANOTHER CO',
#        'EMS: FIRE POLICE NEEDED', 'Fire: PRISONER IN CUSTODY',
#        'EMS: TRASH/DUMPSTER FIRE', 'Fire: SUSPICIOUS',
#        'Fire: SUBJECT IN PAIN', 'Fire: RESPIRATORY EMERGENCY',
#        'Fire: SUICIDE ATTEMPT', 'Fire: NAUSEA/VOMITING',
#        'Fire: PUBLIC SERVICE', 'Fire: OVERDOSE', 'Fire: HEAD INJURY',
#        'EMS: BOMB THREAT', 'Fire: GENERAL WEAKNESS',
#        'Fire: ELEVATOR EMERGENCY', 'EMS: ELEVATOR EMERGENCY',
#        'Fire: HAZARDOUS ROAD CONDITIONS', 'EMS: PUBLIC SERVICE',
#        'EMS: VEHICLE LEAKING FUEL', 'Fire: POISONING',
#        'EMS: POLICE INFORMATION'], dtype=object)

# %%
df['title'].nunique()
# Out:
# 141

# %% [markdown]
# ## Creating new features

# %% [markdown]
# ** In the titles column there are "Reasons/Departments" specified before the title code. These are EMS, Fire, and Traffic. Use .apply() with a custom lambda expression to create a new column called "Reason" that contains this string value.**
#
# **For example, if the title column value is EMS: BACK PAINS/INJURY , the Reason column value would be EMS. **

# %%
x=df['title'].iloc[0]
x.split(":")[0]
# Out:
# 'EMS'

# %%
df['Reason']=df['title'].apply(lambda title: title.split(":")[0])

# %%
df
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# 5       40.253473 -75.283245
# 6       40.182111 -75.127795
# 7       40.217286 -75.405182
# 8       40.289027 -75.399590
# 9       40.102398 -75.291458
# 10      40.231990 -75.251891
# 11      40.084161 -75.308386
# 12      40.174131 -75.098491
# 13      40.062974 -75.135914
# 14      40.097222 -75.376195
# 15      40.223778 -75.235399
# 16      40.243258 -75.286552
# 17      40.312181 -75.574260
# 22          UPPER GWYNEDD                    LILAC CT & PRIMROSE DR  1
# 23       LOWER PROVIDENCE             RT422  & PAWLINGS RD OVERPASS  1
# 24           UPPER DUBLIN              SUMMIT AVE & RT309 UNDERPASS  1
# 25       LOWER PROVIDENCE         SHANNONDELL DR & SHANNONDELL BLVD  1
# 26               WHITPAIN      PENLLYN BLUE BELL PIKE & VILLAGE CIR  1
# 27        DELAWARE COUNTY                    EDENTON PL & DURHAM DR  1
# 28           UPPER MERION     SCHUYLKILL EXPY & WEADLEY RD OVERPASS  1
# 29                HORSHAM                COUNTY LINE RD & WILLOW DR  1
# ...                   ...                                       ... ..
# 423879        NEW HANOVER                     BUCHERT RD & ROMIG RD  1
# 423880         CHELTENHAM               RICES MILL RD & W CHURCH RD  1
# 423881            HORSHAM                     TENNIS AVE & WELSH RD  1
# 423882       UPPER DUBLIN                     WELSH RD & TENNIS AVE  1
# 423883            HORSHAM                     SUMMIT AVE & RUTH AVE  1
# 423884  HATFIELD TOWNSHIP            BETHLEHEM PIKE & TREWIGTOWN RD  1
# 423885        NEW HANOVER                      HENNING RD & HILL RD  1
# 423886    LOWER FREDERICK                 YERGER RD & N RYANFORD RD  1
# 423887      WEST NORRITON                      BEECH DR & SPRUCE ST  1
# 423888           LIMERICK         LIGHTCAP RD & SANATOGA SPRINGS DR  1
# 423889     UPPER MORELAND                  MORELAND RD & BARTRAM RD  1
# 423890        NEW HANOVER                                HENNING RD  1
# 423891     UPPER MORELAND                  MORELAND RD & BARTRAM RD  1
# 423892           ABINGTON                   THE FAIRWAY  & RYDAL RD  1
# 423893  HATFIELD TOWNSHIP                      LINE ST & COWPATH RD  1
# 423894         ROYERSFORD                         MAIN ST & 2ND AVE  1
# 423895           WHITPAIN                  TWIN SILO DR & MORRIS RD  1
# 423896      UPPER SALFORD                                   HOFFMAN  1
# 423897       UPPER DUBLIN               W MORELAND RD & KIMBALL AVE  1
# 423898   UPPER PROVIDENCE              MAC DADE RD & SCARLET OAK DR  1
# 423899       UPPER DUBLIN               W MORELAND RD & KIMBALL AVE  1
# 423900             AMBLER                                   HOFFMAN  1
# 423901   LOWER PROVIDENCE         SHANNONDELL DR & SHANNONDELL BLVD  1
# 423902         MONTGOMERY            RICHARDSON RD & COUNTY LINE RD  1
# 423903         MONTGOMERY                     HORSHAM RD & STUMP RD  1
# 423904     LOWER MORELAND                     BUCK RD & WOODWARD DR  1
# 423905      LOWER SALFORD                         OAK DR & MOYER RD  1
# 423906      LOWER SALFORD                         OAK DR & MOYER RD  1
# 423907      LOWER GWYNEDD           SUMNEYTOWN PIKE & WELLINGTON DR  1
# 423908      LOWER GWYNEDD                                   HOFFMAN  1
#
#          Reason
# 0           EMS
# 1           EMS
# 2          Fire
# 3           EMS
# 4           EMS
# 5           EMS
# 6           EMS
# 7           EMS
# 8           EMS
# 9       Traffic
# 10      Traffic
# 11      Traffic
# 12      Traffic
# 13      Traffic
# 14      Traffic
# 15      Traffic
# 16          EMS
# 17          EMS
# 18          EMS
# 19      Traffic
# 20      Traffic
# 21      Traffic
# 22         Fire
# 23      Traffic
# 24      Traffic
# 25          EMS
# 26          EMS
# 27         Fire
# 28      Traffic
# 29      Traffic
# ...         ...
# 423879  Traffic
# 423880  Traffic
# 423881  Traffic
# 423882  Traffic
# 423883      EMS
# 423884     Fire
# 423885  Traffic
# 423886  Traffic
# 423887      EMS
# 423888     Fire
# 423889  Traffic
# 423890     Fire
# 423891  Traffic
# 423892     Fire
# 423893     Fire
# 423894      EMS
# 423895      EMS
# 423896  Traffic
# 423897  Traffic
# 423898  Traffic
# 423899  Traffic
# 423900  Traffic
# 423901      EMS
# 423902  Traffic
# 423903  Traffic
# 423904  Traffic
# 423905  Traffic
# 423906  Traffic
# 423907  Traffic
# 423908  Traffic
#
# [423909 rows x 10 columns]

# %% [markdown]
# ** What is the most common Reason for a 911 call based off of this new column? **

# %%
df['Reason'].value_counts()
# Out:
# EMS        208676
# Traffic    151458
# Fire        63775
# Name: Reason, dtype: int64

# %% [markdown]
# ** Now use seaborn to create a countplot of 911 calls by Reason. **

# %%
import seaborn as sns
# sns.countplot()
sns.countplot(x='Reason',data=df)

# %% [markdown]
# ___
# ** Now let us begin to focus on time information. What is the data type of the objects in the timeStamp column? **

# %%
df.iloc[2]
# Out:
# lat                                                    40.1212
# lng                                                    -75.352
# desc         HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# zip                                                      19401
# title                                      Fire: GAS-ODOR/LEAK
# timeStamp                                  2015-12-10 14:39:21
# twp                                                 NORRISTOWN
# addr                                                  HAWS AVE
# e                                                            1
# Reason                                                    Fire
# Name: 2, dtype: object

# %%
df['timeStamp'].iloc[0]
# Out:
# '2015-12-10 17:10:52'

# %%
type(df['timeStamp'].iloc[0])
# Out:
# str

# %%
# df['timeStamp']g
df['timeStamp']=pd.to_datetime(df['timeStamp'])

# %%
type(df['timeStamp'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# ** You should have seen that these timestamps are still strings. Use [pd.to_datetime](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html) to convert the column from strings to DateTime objects. **

# %% [markdown]
# ** You can now grab specific attributes from a Datetime object by calling them. For example:**
#
#     time = df['timeStamp'].iloc[0]
#     time.hour
#
# **You can use Jupyter's tab method to explore the various attributes you can call. Now that the timestamp column are actually DateTime objects, use .apply() to create 3 new columns called Hour, Month, and Day of Week. You will create these columns based off of the timeStamp column, reference the solutions if you get stuck on this step.**

# %%
time = df['timeStamp'].iloc[3]
# time.hour
# time.day
# time.year
# time.dayofweek

# %%
Dw=df['timeStamp'].apply(lambda time: time.dayofweek)
# Dw.map(dmap,na_action='ignore')
# Day_of_week
hour=df['timeStamp'].apply(lambda hr: hr.hour)
month=df['timeStamp'].apply(lambda m:m.month)

# %%
df['Day_of_week']=Dw
df['Hour']=hour
df['Month']=month

# %%
df
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# 5       40.253473 -75.283245
# 6       40.182111 -75.127795
# 7       40.217286 -75.405182
# 8       40.289027 -75.399590
# 28         Traffic: VEHICLE ACCIDENT - 2015-12-10 18:05:39       UPPER MERION
# 29         Traffic: DISABLED VEHICLE - 2015-12-10 18:10:40            HORSHAM
# ...                                ...                 ...                ...
# 423879     Traffic: DISABLED VEHICLE - 2018-11-16 08:18:15        NEW HANOVER
# 423880     Traffic: ROAD OBSTRUCTION - 2018-11-16 08:18:08         CHELTENHAM
# 423881     Traffic: VEHICLE ACCIDENT - 2018-11-16 08:17:59            HORSHAM
# 423882     Traffic: VEHICLE ACCIDENT - 2018-11-16 08:14:32       UPPER DUBLIN
# 423883            EMS: SUBJECT IN PAIN 2018-11-16 08:27:45            HORSHAM
# 423884        Fire: FIRE INVESTIGATION 2018-11-16 08:30:54  HATFIELD TOWNSHIP
# 423885     Traffic: DISABLED VEHICLE - 2018-11-16 08:29:22        NEW HANOVER
# 423886     Traffic: DISABLED VEHICLE - 2018-11-16 08:30:00    LOWER FREDERICK
# 423887                   EMS: SEIZURES 2018-11-16 08:39:28      WEST NORRITON
# 423888                Fire: FIRE ALARM 2018-11-16 08:39:53           LIMERICK
# 423889     Traffic: VEHICLE ACCIDENT - 2018-11-16 08:38:23     UPPER MORELAND
# 423890        Fire: FIRE POLICE NEEDED 2018-11-16 08:45:04        NEW HANOVER
# 423891     Traffic: VEHICLE ACCIDENT - 2018-11-16 08:46:39     UPPER MORELAND
# 423892                Fire: FIRE ALARM 2018-11-16 08:49:48           ABINGTON
# 423893        Fire: FIRE INVESTIGATION 2018-11-16 08:48:24  HATFIELD TOWNSHIP
# 423894                EMS: FALL VICTIM 2018-11-16 08:50:58         ROYERSFORD
# 423895           EMS: SYNCOPAL EPISODE 2018-11-16 08:47:05           WHITPAIN
# 423896     Traffic: DISABLED VEHICLE - 2018-11-16 08:46:25      UPPER SALFORD
# 423897     Traffic: VEHICLE ACCIDENT - 2018-11-16 08:46:39       UPPER DUBLIN
# 423898     Traffic: DISABLED VEHICLE - 2018-11-16 08:43:42   UPPER PROVIDENCE
# 423899     Traffic: VEHICLE ACCIDENT - 2018-11-16 08:38:23       UPPER DUBLIN
# 423900     Traffic: DISABLED VEHICLE - 2018-11-16 08:46:25             AMBLER
# 423901        EMS: MEDICAL ALERT ALARM 2018-11-16 08:53:03   LOWER PROVIDENCE
# 423902     Traffic: DISABLED VEHICLE - 2018-11-16 08:55:36         MONTGOMERY
# 423903     Traffic: DISABLED VEHICLE - 2018-11-16 08:54:52         MONTGOMERY
# 423904     Traffic: VEHICLE ACCIDENT - 2018-11-16 08:54:08     LOWER MORELAND
# 423905     Traffic: VEHICLE ACCIDENT - 2018-11-16 08:53:32      LOWER SALFORD
# 423906     Traffic: VEHICLE ACCIDENT - 2018-11-16 08:54:19      LOWER SALFORD
# 423907     Traffic: VEHICLE ACCIDENT - 2018-11-16 08:51:48      LOWER GWYNEDD
# 423908     Traffic: DISABLED VEHICLE - 2018-11-16 08:46:25      LOWER GWYNEDD
#
#                                             addr  e   Reason  Day_of_week  \
# 0                         REINDEER CT & DEAD END  1      EMS            3
# 1                     BRIAR PATH & WHITEMARSH LN  1      EMS            3
# 2                                       HAWS AVE  1     Fire            3
# 3                             AIRY ST & SWEDE ST  1      EMS            3
# 4                       CHERRYWOOD CT & DEAD END  1      EMS            3
# 5                          CANNON AVE & W 9TH ST  1      EMS            3
# 6                       LAUREL AVE & OAKDALE AVE  1      EMS            3
# 7                   COLLEGEVILLE RD & LYWISKI RD  1      EMS            3
# 8                  MAIN ST & OLD SUMNEYTOWN PIKE  1      EMS            3
# 9       BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD  1  Traffic            3
# 10                         RT202 PKWY & KNAPP RD  1  Traffic            3
# 11                         BROOK RD & COLWELL LN  1  Traffic            3
# 12                 BYBERRY AVE & S WARMINSTER RD  1  Traffic            3
# 13                       OLD YORK RD & VALLEY RD  1  Traffic            3
# 14         SCHUYLKILL EXPY & CROTON RD UNDERPASS  1  Traffic            3
# 15                       STUMP RD & WITCHWOOD DR  1  Traffic            3
# 16                   SUSQUEHANNA AVE & W MAIN ST  1      EMS            3
# 17                       CHARLOTTE ST & MILES RD  1      EMS            3
# 18                             PENN ST & ARCH ST  1      EMS            3
# 19                    COUNTY LINE RD & WILLOW DR  1  Traffic            3
# 20                             PENN ST & ARCH ST  1  Traffic            3
# 21                        CHURCH RD & REDCOAT DR  1  Traffic            3
# 22                        LILAC CT & PRIMROSE DR  1     Fire            3
# 23                 RT422  & PAWLINGS RD OVERPASS  1  Traffic            3
# 24                  SUMMIT AVE & RT309 UNDERPASS  1  Traffic            3
# 25             SHANNONDELL DR & SHANNONDELL BLVD  1      EMS            3
# 26          PENLLYN BLUE BELL PIKE & VILLAGE CIR  1      EMS            3
# 27                        EDENTON PL & DURHAM DR  1     Fire            3
# 28         SCHUYLKILL EXPY & WEADLEY RD OVERPASS  1  Traffic            3
# 29                    COUNTY LINE RD & WILLOW DR  1  Traffic            3
# ...                                          ... ..      ...          ...
# 423879                     BUCHERT RD & ROMIG RD  1  Traffic            4
# 423880               RICES MILL RD & W CHURCH RD  1  Traffic            4
# 423881                     TENNIS AVE & WELSH RD  1  Traffic            4
# 423882                     WELSH RD & TENNIS AVE  1  Traffic            4
# 423883                     SUMMIT AVE & RUTH AVE  1      EMS            4
# 423884            BETHLEHEM PIKE & TREWIGTOWN RD  1     Fire            4
# 423885                      HENNING RD & HILL RD  1  Traffic            4
# 423886                 YERGER RD & N RYANFORD RD  1  Traffic            4
# 423887                      BEECH DR & SPRUCE ST  1      EMS            4
# 423888         LIGHTCAP RD & SANATOGA SPRINGS DR  1     Fire            4
# 423889                  MORELAND RD & BARTRAM RD  1  Traffic            4
# 423890                                HENNING RD  1     Fire            4
# 423891                  MORELAND RD & BARTRAM RD  1  Traffic            4
# 423892                   THE FAIRWAY  & RYDAL RD  1     Fire            4
# 423893                      LINE ST & COWPATH RD  1     Fire            4
# 423894                         MAIN ST & 2ND AVE  1      EMS            4
# 423895                  TWIN SILO DR & MORRIS RD  1      EMS            4
# 423896                                   HOFFMAN  1  Traffic            4
# 423897               W MORELAND RD & KIMBALL AVE  1  Traffic            4
# 423898              MAC DADE RD & SCARLET OAK DR  1  Traffic            4
# 423899               W MORELAND RD & KIMBALL AVE  1  Traffic            4
# 423900                                   HOFFMAN  1  Traffic            4
# 423901         SHANNONDELL DR & SHANNONDELL BLVD  1      EMS            4
# 423902            RICHARDSON RD & COUNTY LINE RD  1  Traffic            4
# 423903                     HORSHAM RD & STUMP RD  1  Traffic            4
# 423904                     BUCK RD & WOODWARD DR  1  Traffic            4
# 423905                         OAK DR & MOYER RD  1  Traffic            4
# 423906                         OAK DR & MOYER RD  1  Traffic            4
# 423907           SUMNEYTOWN PIKE & WELLINGTON DR  1  Traffic            4
# 423908                                   HOFFMAN  1  Traffic            4
#
#         Hour  Month
# 0         17     12
# 1         17     12
# 2         14     12
# 3         16     12
# 4         16     12
# 5         15     12
# 6         16     12
# 7         16     12
# 8         16     12
# 9         17     12
# 10        17     12
# 11        16     12
# 12        17     12
# 13        17     12
# 14        17     12
# 15        17     12
# 16        17     12
# 17        17     12
# 18        17     12
# 19        17     12
# 20        17     12
# 21        17     12
# 22        17     12
# 23        18     12
# 24        17     12
# 25        18     12
# 26        18     12
# 27        18     12
# 28        18     12
# 29        18     12
# ...      ...    ...
# 423879     8     11
# 423880     8     11
# 423881     8     11
# 423882     8     11
# 423883     8     11
# 423884     8     11
# 423885     8     11
# 423886     8     11
# 423887     8     11
# 423888     8     11
# 423889     8     11
# 423890     8     11
# 423891     8     11
# 423892     8     11
# 423893     8     11
# 423894     8     11
# 423895     8     11
# 423896     8     11
# 423897     8     11
# 423898     8     11
# 423899     8     11
# 423900     8     11
# 423901     8     11
# 423902     8     11
# 423903     8     11
# 423904     8     11
# 423905     8     11
# 423906     8     11
# 423907     8     11
# 423908     8     11
#
# [423909 rows x 13 columns]

# %% [markdown]
# ** Notice how the Day of Week is an integer 0-6. Use the .map() with this dictionary to map the actual string names to the day of the week: **
#
#     dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}

# %%
dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}

# %%
df['Day_of_week']=df['Day_of_week'].map(dmap,na_action='ignore')

# if na_action is set to ignore, it ignores NaN values from being passed to the map()

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title           timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY 2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY 2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK 2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY 2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS 2015-12-10 16:56:52   LOWER POTTSGROVE
#
#                          addr  e Reason Day_of_week  Hour  Month
# 0      REINDEER CT & DEAD END  1    EMS         Thu    17     12
# 1  BRIAR PATH & WHITEMARSH LN  1    EMS         Thu    17     12
# 2                    HAWS AVE  1   Fire         Thu    14     12
# 3          AIRY ST & SWEDE ST  1    EMS         Thu    16     12
# 4    CHERRYWOOD CT & DEAD END  1    EMS         Thu    16     12

# %% [markdown]
# ** Now use seaborn to create a countplot of the Day of Week column with the hue based off of the Reason column. **

# %%
df['Day_of_week']
# Out:
# 0         Thu
# 1         Thu
# 2         Thu
# 3         Thu
# 4         Thu
# 5         Thu
# 6         Thu
# 7         Thu
# 8         Thu
# 9         Thu
# 10        Thu
# 11        Thu
# 12        Thu
# 13        Thu
# 14        Thu
# 15        Thu
# 16        Thu
# 17        Thu
# 18        Thu
# 19        Thu
# 20        Thu
# 21        Thu
# 22        Thu
# 23        Thu
# 24        Thu
# 25        Thu
# 26        Thu
# 27        Thu
# 28        Thu
# 29        Thu
#          ...
# 423879    Fri
# 423880    Fri
# 423881    Fri
# 423882    Fri
# 423883    Fri
# 423884    Fri
# 423885    Fri
# 423886    Fri
# 423887    Fri
# 423888    Fri
# 423889    Fri
# 423890    Fri
# 423891    Fri
# 423892    Fri
# 423893    Fri
# 423894    Fri
# 423895    Fri
# 423896    Fri
# 423897    Fri
# 423898    Fri
# 423899    Fri
# 423900    Fri
# 423901    Fri
# 423902    Fri
# 423903    Fri
# 423904    Fri
# 423905    Fri
# 423906    Fri
# 423907    Fri
# 423908    Fri
# Name: Day_of_week, Length: 423909, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='Day_of_week',hue='Reason',data=df)
# to place legen outside the plot,
# use the bbox_to_anchor keyword argument we can shift the
# legend slightly outside the axes boundaries

plt.legend(bbox_to_anchor=(1.05,1))

# %% [markdown]
# **Now do the same for Month:**

# %%
sns.countplot(x='Month',hue='Reason',data=df,palette='Set2')
plt.legend(bbox_to_anchor=(.05,1))

# %% [markdown]
# **Did you notice something strange about the Plot?**
#
# _____
#
# ** You should have noticed it was missing some Months, let's see if we can maybe fill in this information by plotting the information in another way, possibly a simple line plot that fills in the missing months, in order to do this, we'll need to do some work with pandas... **

# %% [markdown]
# ** Now create a gropuby object called byMonth, where you group the DataFrame by the month column and use the count() method for aggregation. Use the head() method on this returned DataFrame. **

# %%
bymonth=df.groupby(by='Month').count()

# %%
bymonth.head()
# Out:
#          lat    lng   desc    zip  title  timeStamp    twp   addr      e  \
# Month
# 1      37824  37824  37824  33480  37824      37824  37812  37824  37824
# 2      32828  32828  32828  28963  32828      32828  32817  32828  32828
# 3      37666  37666  37666  33416  37666      37666  37651  37666  37666
# 4      33583  33583  33583  29488  33583      33583  33575  33583  33583
# 5      35644  35644  35644  31114  35644      35644  35628  35644  35644
#
#        Reason  Day_of_week   Hour
# Month
# 1       37824        37824  37824
# 2       32828        32828  32828
# 3       37666        37666  37666
# 4       33583        33583  33583
# 5       35644        35644  35644

# %% [markdown]
# ** Now create a simple plot off of the dataframe indicating the count of calls per month. **

# %%
sns.countplot(x='Month',data=df)

# %% [markdown]
# ** Now see if you can use seaborn's lmplot() to create a linear fit on the number of calls per month. Keep in mind you may need to reset the index to a column. **

# %%
df.reset_index(inplace=True,drop=True)
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title           timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY 2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY 2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK 2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY 2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS 2015-12-10 16:56:52   LOWER POTTSGROVE
#
#                          addr  e Reason Day_of_week  Hour  Month
# 0      REINDEER CT & DEAD END  1    EMS         Thu    17     12
# 1  BRIAR PATH & WHITEMARSH LN  1    EMS         Thu    17     12
# 2                    HAWS AVE  1   Fire         Thu    14     12
# 3          AIRY ST & SWEDE ST  1    EMS         Thu    16     12
# 4    CHERRYWOOD CT & DEAD END  1    EMS         Thu    16     12

# %% [markdown]
# ** Now see if you can use seaborn's lmplot() to create a linear fit on the number of calls per month. Keep in mind you may need to reset the index to a column. **

# %%
sns.lmplot(data=bymonth.reset_index(),x='Month',y='twp')

# %% [markdown]
# **Create a new column called 'Date' that contains the date from the timeStamp column. You'll need to use apply along with the .date() method. **

# %%
type(df['timeStamp'].iloc[2])
df['timeStamp']=pd.to_datetime(df['timeStamp'])

# %%
Date=df['timeStamp'].apply(lambda x: x.date())
df['Date']=Date
df
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# 5       40.253473 -75.283245
# 6       40.182111 -75.127795
# 7       40.217286 -75.405182
# 8       40.289027 -75.399590
# 9       40.102398 -75.291458
# 10      40.231990 -75.251891
# 11      40.084161 -75.308386
# 12      40.174131 -75.098491
# 13      40.062974 -75.135914
# 14      40.097222 -75.376195
# 15      40.223778 -75.235399
# 16      40.243258 -75.286552
# 17      40.312181 -75.574260
# 18      40.114239 -75.338508
# 19      40.209337 -75.135266
# 20      40.114239 -75.338508
# 21      40.117948 -75.209848
# 22      40.199006 -75.300058
# 23      40.143326 -75.422819
# 24      40.153268 -75.189558
# 25      40.133037 -75.408463
# 26      40.155283 -75.264230
# 27      40.028903 -75.351822
# 28      40.097222 -75.376195
# 29      40.209337 -75.135266
# ...           ...        ...
# 423879  40.284894 -75.583070
# 423880  40.089043 -75.154857
# 423881  40.188195 -75.195506
# 423882  40.188195 -75.195506
# 423883  40.175671 -75.125148
# 423884  40.277468 -75.260462
# 423885  40.345292 -75.509276
# 423886  40.260591 -75.503238
# 423887  40.136020 -75.354606
# 423888  40.230934 -75.522125
# 423889  40.150675 -75.132652
# 423890  40.335354 -75.511268
# 423891  40.150675 -75.132652
# 423892  40.107400 -75.113206
# 423893  40.256628 -75.261270
# 423894  40.183361 -75.542285
# 423895  40.184797 -75.286879
# 423896  40.254344 -75.407617
# 423897  40.149952 -75.134537
# 423898  40.142797 -75.495065
# 423899  40.149952 -75.134537
# 423900  40.157913 -75.203632
# 423901  40.133037 -75.408463
# 423902  40.271663 -75.238440
# 423903  40.235373 -75.224751
# 423904  40.139993 -75.049864
# 423905  40.270121 -75.382825
# 423906  40.270121 -75.382825
# 423907  40.190946 -75.237285
# 423908  40.155164 -75.264665
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# 5       CANNON AVE & W 9TH ST;  LANSDALE; Station 345;...  19446.0
# 6       LAUREL AVE & OAKDALE AVE;  HORSHAM; Station 35...  19044.0
# 7       COLLEGEVILLE RD & LYWISKI RD;  SKIPPACK; Stati...  19426.0
# 8       MAIN ST & OLD SUMNEYTOWN PIKE;  LOWER SALFORD;...  19438.0
# 9       BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD; PLYM...  19462.0
# 10      RT202 PKWY & KNAPP RD; MONTGOMERY; 2015-12-10 ...      NaN
# 11      BROOK RD & COLWELL LN; PLYMOUTH; 2015-12-10 @ ...  19428.0
# 12      BYBERRY AVE & S WARMINSTER RD; UPPER MORELAND;...  19040.0
# 13      OLD YORK RD & VALLEY RD; CHELTENHAM; 2015-12-1...  19027.0
# 14      SCHUYLKILL EXPY & CROTON RD UNDERPASS; UPPER M...      NaN
Traffic: VEHICLE ACCIDENT - 2018-11-16 08:54:19      LOWER SALFORD
# 423907     Traffic: VEHICLE ACCIDENT - 2018-11-16 08:51:48      LOWER GWYNEDD
# 423908     Traffic: DISABLED VEHICLE - 2018-11-16 08:46:25      LOWER GWYNEDD
#
#                                             addr  e   Reason Day_of_week  \
# 0                         REINDEER CT & DEAD END  1      EMS         Thu
# 1                     BRIAR PATH & WHITEMARSH LN  1      EMS         Thu
# 2                                       HAWS AVE  1     Fire         Thu
# 3                             AIRY ST & SWEDE ST  1      EMS         Thu
# 4                       CHERRYWOOD CT & DEAD END  1      EMS         Thu
# 5                          CANNON AVE & W 9TH ST  1      EMS         Thu
# 6                       LAUREL AVE & OAKDALE AVE  1      EMS         Thu
# 7                   COLLEGEVILLE RD & LYWISKI RD  1      EMS         Thu
# 8                  MAIN ST & OLD SUMNEYTOWN PIKE  1      EMS         Thu
# 9       BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD  1  Traffic         Thu
# 10                         RT202 PKWY & KNAPP RD  1  Traffic         Thu
# 11                         BROOK RD & COLWELL LN  1  Traffic         Thu
# 12                 BYBERRY AVE & S WARMINSTER RD  1  Traffic         Thu
# 13                       OLD YORK RD & VALLEY RD  1  Traffic         Thu
# 14         SCHUYLKILL EXPY & CROTON RD UNDERPASS  1  Traffic         Thu
# 15                       STUMP RD & WITCHWOOD DR  1  Traffic         Thu
# 16                   SUSQUEHANNA AVE & W MAIN ST  1      EMS         Thu
# 17                       CHARLOTTE ST & MILES RD  1      EMS         Thu
# 18                             PENN ST & ARCH ST  1      EMS         Thu
# 19                    COUNTY LINE RD & WILLOW DR  1  Traffic         Thu
# 20                             PENN ST & ARCH ST  1  Traffic         Thu
# 21                        CHURCH RD & REDCOAT DR  1  Traffic         Thu
# 22                        LILAC CT & PRIMROSE DR  1     Fire         Thu
# 23                 RT422  & PAWLINGS RD OVERPASS  1  Traffic         Thu
# 24                  SUMMIT AVE & RT309 UNDERPASS  1  Traffic         Thu
# 25             SHANNONDELL DR & SHANNONDELL BLVD  1      EMS         Thu
# 26          PENLLYN BLUE BELL PIKE & VILLAGE CIR  1      EMS         Thu
# 27                        EDENTON PL & DURHAM DR  1     Fire         Thu
# 28         SCHUYLKILL EXPY & WEADLEY RD OVERPASS  1  Traffic         Thu
# 29                    COUNTY LINE RD & WILLOW DR  1  Traffic         Thu
# ...                                          ... ..      ...         ...
# 423879                     BUCHERT RD & ROMIG RD  1  Traffic         Fri
# 423880               RICES MILL RD & W CHURCH RD  1  Traffic         Fri
# 423881                     TENNIS AVE & WELSH RD  1  Traffic         Fri
# 423882                     WELSH RD & TENNIS AVE  1  Traffic         Fri
# 423883                     SUMMIT AVE & RUTH AVE  1      EMS         Fri
# 423884            BETHLEHEM PIKE & TREWIGTOWN RD  1     Fire         Fri
# 423885                      HENNING RD & HILL RD  1  Traffic         Fri
# 423886                 YERGER RD & N RYANFORD RD  1  Traffic         Fri
# 423887                      BEECH DR & SPRUCE ST  1      EMS         Fri
# 423888         LIGHTCAP RD & SANATOGA SPRINGS DR  1     Fire         Fri
# 423889                  MORELAND RD & BARTRAM RD  1  Traffic         Fri
# 423890                                HENNING RD  1     Fire         Fri
# 423891                  MORELAND RD & BARTRAM RD  1  Traffic         Fri
# 423892                   THE FAIRWAY  & RYDAL RD  1     Fire         Fri
# %%
df.groupby('Date').count()['zip']
# Out:
# Date
# 2015-12-10     100
# 2015-12-11     332
# 2015-12-12     334
# 2015-12-13     279
# 2015-12-14     386
# 2015-12-15     380
# 2015-12-16     343
# 2015-12-17     336
# 2015-12-18     306
# 2015-12-19     239
# 2015-12-20     236
# 2015-12-21     376
# 2015-12-22     399
# 2015-12-23     430
# 2015-12-24     387
# 2015-12-25     266
# 2015-12-26     258
# 2015-12-27     290
# 2015-12-28     337
# 2015-12-29     315
# 2015-12-30     305
# 2015-12-31     268
# 2016-01-01     236
# 2016-01-02     300
# 2016-01-03     284
# 2016-01-04     345
# 2016-01-05     373
# 2016-01-06     375
# 2016-01-07     334
# 2016-01-08     326
#               ...
# 2018-10-18     367
# 2018-10-19     341
# 2018-10-20     360
# 2018-10-21     283
# 2018-10-22     377
# 2018-10-23     385
# 2018-10-24     354
# 2018-10-25     370
# 2018-10-26     391
# 2018-10-27     397
# 2018-10-28     269
# 2018-10-29     383
# 2018-10-30     384
# 2018-10-31     440
# 2018-11-01     325
# 2018-11-02     482
# 2018-11-03     562
# 2018-11-04     281
# 2018-11-05     401
# 2018-11-06     441
# 2018-11-07     389
# 2018-11-08     399
# 2018-11-09     418
# 2018-11-10     379
# 2018-11-11     269
# 2018-11-12     389
# 2018-11-13     371
# 2018-11-14     350
# 2018-11-15    1458
# 2018-11-16     135
# Name: zip, Length: 1073, dtype: int64

# %%
dategrp=df.groupby(by='Date').count()['zip']
# sns.countplot(df['Date'],data=df)
dategrp.plot()
plt.tight_layout()

# %% [markdown]
# ** Now recreate this plot but create 3 separate plots with each plot representing a Reason for the 911 call**

# %%
df[df['Reason']=='EMS'].groupby('Date').count()['zip'].plot()
plt.tight_layout()
plt.title('EMS')
# Out:
# Text(0.5, 1.0, 'EMS')

# %%
df[df['Reason']=='Traffic'].groupby('Date').count()['lat'].plot()
plt.tight_layout()
plt.title('Traffic')
# Out:
# Text(0.5, 1.0, 'Traffic')

# %% [markdown]
# ____
# ** Now let's move on to creating  heatmaps with seaborn and our data. We'll first need to restructure the dataframe so that the columns become the Hours and the Index becomes the Day of the Week. There are lots of ways to do this, but I would recommend trying to combine groupby with an [unstack](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.unstack.html) method. Reference the solutions if you get stuck on this!**

# %%
dayhr=df.groupby(by=['Day_of_week','Hour']).count()['Reason'].unstack()

# %% [markdown]
# ** Now create a HeatMap using this new DataFrame. **

# %%
# make the plot bigger
plt.figure(figsize=[15,10])
sns.heatmap(dayhr,cmap='viridis',)

# %% [markdown]
# ** Now create a clustermap using this DataFrame. **

# %%
sns.clustermap(dayhr,figsize=[15,10],cmap='viridis')

# %% [markdown]
# ** Now repeat these same plots and operations, for a DataFrame that shows the Month as the column. **

# %%
daymonth=df.groupby(['Day_of_week','Month']).count()['Reason'].unstack()

# %%
plt.figure(figsize=[15,10])
sns.heatmap(daymonth,cmap='viridis')

# %%
sns.clustermap(daymonth,cmap='viridis')

# %% [markdown]
# **Continue exploring the Data however you see fit!**
# # Great Job!
