# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Matplotlib is the whole package and matplotlib.pyplot is a module in Matplotlib.

# %%
# %matplotlib inline



# the output of plotting commands is displayed inline within frontends 
# like the Jupyter notebook, directly below the code cell that produced it.
# The resulting plots will then also be stored in the notebook document.

# %%
x=np.linspace(0,6,9)
y=np.linspace(3,9,9)

# %%
# to plot the relationship b/w both the arrays
# we use matplotlib library

# %%
plt.plot(x,y)

# %%
# heere v plot a linear graph ie a straight line from one edge to another edge

# %%
x=np.arange(0,10,2)

# %%
x
# Out:
# array([0, 2, 4, 6, 8])

# %%
y=x**2

# here values of y is 2 times the values of x.
# so the shape of graph changes

# %%
plt.plot(x,y)

# %% [markdown]
# **Simple Plot**

# %%
import matplotlib.pyplot as plt
x=np.linspace(0,10,20)
plt.plot(x,x,label='linear')
# here v label it as a linear
plt.plot(x,x**2,label='quadratic')
plt.plot(x,x**3,label='Cubic')
plt.xlabel('xaxis')
plt.ylabel('yaxis')
plt.title('Simple Plot')
plt.legend()
plt.show()

# %% [markdown]
# For functions in the pyplot module, there is always a "current" figure
# and axes (which is created automatically on request). For example, in the following example,
# the first call to plt.plot creates the axes, then subsequent calls to plt.plot add additional
# lines on the same axes, and plt.xlabel, plt.ylabel, plt.title
# and plt.legend set the axes labels and title and add a legend.

# %% [markdown]
# # ploting categorical variables using pyplot

# %%
import matplotlib.pyplot as plt
category=['HEALTH','SCIENCE','TECH','FASHION']
contents=[40,80,120,150]
plt.figure(figsize=[15,7])
plt.bar(category,contents)
plt.xlabel('category')
plt.ylabel('No.of Contents')
plt.show()

# %% [markdown]
# plt.figure(
#     num=None,
#     figsize=None,
#     dpi=None,
#     facecolor=None,
#     edgecolor=None,
#     frameon=True,
#     FigureClass=<class 'matplotlib.figure.Figure'>,
#     clear=False,
#     **kwargs,
# )
# Docstring:
# Create a new figure.
#
# #figsize is to set the resolution of fig ie width and height
#
# plt.bar() : -to make a bar plot,
# pass the cordinates to be plotted. ie here it is category(x-axis) and contents(y axis)

# %% [markdown]
# # ploting Piecharts

# %% [markdown]
# # What are Pie Charts?
#
#
# An Emma chart (or a circle chart) is a circular statistical graphic which is divided into slices to illustrate numerical proportion. In a pie chart, the arc length of each slice (and consequently its central angle and area), is proportional to the quantity it represents

# %%
import matplotlib.pyplot as plt
import numpy as np
# sub_df=pd.DataFrame(''),
types=['Comedy',"Action",'Romance','Drama',"Sci-Fi"]
likes=[13,6,7,20,15]
data_arr=np.array(likes)
colors=['green','red',"blue",'yellow','purple']
plt.pie(data_arr,labels=types,colors=colors,autopct='%.2f')
plt.title("Favourite type of Movie")
plt.show()

# %% [markdown]
# Here v plot a peie cart having 5 wedges also called slices

# %% [markdown]
# Here v pass as an array to the pie() note: can also just list.
# later set the labels (here it is types of mvies) andspecify the color for each wedge(each slice).
# and next comes autopct if not declared percent value corresponding to each wedge will not be shown.
# (autopct enables you to display the percent value using Python string formatting.)
# set autopct='%.2f' meaning there is 2 decimal values after the decimal point.
# oto show % symbol after the value just use '%%' after '2f' eg :'%.2f%%'

# %% [markdown]
# **Example**

# %%
# Student Grades.

import matplotlib.pyplot as plt
import numpy as np
grades=['A','B','C','D']
std_no=[14,21,15,10]
std_arr=np.array(std_no)
plt.pie(std_arr,labels=grades,colors=['red',"green",'blue','yellow'],autopct="%.2f%%")
plt.title('Students Grades')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-15cee52b42cc> in <module>
#       6 std_no=[14,21,15,10,6,7]
#       7 std_arr=np.array(std_no)
# ----> 8 plt.pie(std_arr,labels=grades,colors=['red',"green",'blue','yellow'],autopct="%.2f%%")
#       9 plt.title('Students Grades')
#      10 plt.show()
#
# ~/.local/lib/python3.7/site-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2801         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2802         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# -> 2803         data is not None else {}))
#    2804
#    2805
#
# ~/.local/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
import matplotlib.pyplot as plt
plt.bar(np.arange(0,6),np.arange(6,12))
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.title('Data')
# plt.legend()
# Out:
# Text(0.5, 1.0, 'Data')

# %% [markdown]
# # PLOTING HISTOGRAMS USING MATPLOTLIB

# %%
product_ids=[2,2,4,3,5,5,6,4,7,7,4,8,3,9,8,3,3,3,5,3,8,6,6,6,6,6,5,5]
sale_range=np.arange(2,10)
# bins

# %%
plt.hist(product_ids,bins=sale_range,histtype='bar',color='green',rwidth=0.5)
plt.xlabel('frequency of products sold')
plt.ylabel('Product_IDS')
plt.title('Products Analysis')
# Out:
# Text(0.5, 1.0, 'Products Analysis')

# %% [markdown]
# plt.hist(
#     x,
#     bins=None,
#     range=None,
#     density=None,
#     weights=None,
#     cumulative=False,
#     bottom=None,
#     histtype='bar',
#     align='mid',
#     orientation='vertical',
#     rwidth=None,
#     log=False,
#     color=None,
#     label=None,
#     stacked=False,
#     normed=None,
#     *,
#     data=None,
#     **kwargs,
# )
#
#
# Docstring:
# Plot a histogram.

# %% [markdown]
# Here bins means each buckets. ie v group the data into buckets and draw a bar for each bucket or bin.
# for eg: all 2's comes inside bin 2-3 and similarly all 3's comes in bin 3-4

# %%
bins=np.arange(0,62,10)
bins
# people=[]
# Out:
# array([ 0, 10, 20, 30, 40, 50, 60])

# %%
import random
def numbers(start,end,num):
    global data_info
    data_info=[]
    for r in range(num):
        data_info.append(random.randint(start,end))
    return data_info
numbers(0,61,50)
# Out:
# [2,
#  3,
#  50,
#  29,
#  33,
#  58,
#  32,
#  57,
#  47,
#  51,
#  5,
#  49,
#  29,
#  27,
#  9,
#  50,
#  14,
#  59,
#  7,
#  7,
#  43,
#  6,
#  56,
#  43,
#  56,
#  49,
#  10,
#  58,
#  41,
#  42,
#  15,
#  30,
#  58,
#  45,
#  13,
#  17,
#  28,
#  56,
#  44,
#  45,
#  54,
#  21,
#  28,
#  10,
#  47,
#  16,
#  44,
#  13,
#  46,
#  12]

# %%
len(data_info)
# Out:
# 50

# %%
plt.hist(data_info,bins,rwidth=0.5,color='red')
# Out:
# (array([ 8.,  5.,  7.,  9., 10., 11.]),
#  array([ 0, 10, 20, 30, 40, 50, 60]),
#  <a list of 6 Patch objects>)

# %%
print(range(7))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
house_df=pd.read_csv('kc_house_data.csv',)
house_df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data=house_df['sqft_living']

# %%
data
# Out:
# 0        1180
# 1        2570
# 2         770
# 3        1960
# 4        1680
# 5        5420
# 6        1715
# 7        1060
# 8        1780
# 9        1890
# 10       3560
# 11       1160
# 12       1430
# 13       1370
# 14       1810
# 15       2950
# 16       1890
# 17       1600
# 18       1200
# 19       1250
# 20       1620
# 21       3050
# 22       2270
# 23       1070
# 24       2450
# 25       1710
# 26       2450
# 27       1400
# 28       1520
# 29       2570
#          ...
# 21583     710
# 21584    1260
# 21585    1870
# 21586    1430
# 21587    1520
# 21588    1210
# 21589    2540
# 21590    4910
# 21591    2770
# 21592    1190
# 21593    4170
# 21594    2500
# 21595    1530
# 21596    3600
# 21597    3410
# 21598    3118
# 21599    3990
# 21600    4470
# 21601    1425
# 21602    1500
# 21603    2270
# 21604    1490
# 21605    2520
# 21606    3510
# 21607    1310
# 21608    1530
# 21609    2310
# 21610    1020
# 21611    1600
# 21612    1020
# ...

# %% [markdown]
# # pltoing ads Data with Stackplot

# %% [markdown]
# plt.stackplot()
#
# Signature: plt.stackplot(x, *args, data=None, **kwargs)
#
# Docstring:
#
# Draw a stacked area plot.
#
# Parameters
# ----------
# x : 1d array of dimension N
#
# y : 2d array (dimension MxN), or sequence of 1d arrays (each dimension 1xN)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
day=np.arange(1,6)
organic=np.array([8,9,8,3,3])
seller=np.array([9,5,8,9,4])
affiliate=np.array([3,5,5,4,3])
ads=np.array([8,9,7,12,8])
# plt.stackplot(day,seller,affiliate,ads,organic)

# %%
y=np.vstack((organic,seller,affiliate,ads))

# %% [markdown]
# Signature: np.vstack(tup)
#
# Docstring:
#
# Stack arrays in sequence vertically (row wise).
#
#
# Parameters
# ----------
# tup : sequence of ndarrays
#     The arrays must have the same shape along all but the first axis.
#     1-D arrays must have the same length.
#
# Returns
# -------
# stacked : ndarray
#     The array formed by stacking the given arrays, will be at least 2-D.
#
#     Examples
# --------
# a = np.array([1, 2, 3])
#
# b = np.array([2, 3, 4])
#
# np.vstack((a,b))
#
# array([[1, 2, 3],
#        [2, 3, 4]])

# %%
labels=['organic','seller','affiliate','ads']

# %%
plt.stackplot(day,y,labels=labels,colors=['#2c2c54','#34ace0','#218c74','#ff5252'])
# here v pass y which is a 2d array .formed by statcking all the 1d arrays.

plt.legend(loc='best')
plt.title('Company Revenue Scale')
plt.xlabel('Number of days')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# Let's consider a situation where we have 24 hours in a day, and we'd like to see how we're spending our time. We'll divide our activities into: Sleeping, eating, working, and playing.
#
# We're going to assume that we're tracking this over the course of 5 days, so our starting data will look like:

# %%
import matplotlib.pyplot as plt
import numpy as np
days=np.arange(1,6)
sleeping=np.array([5,6,7,9,8])
eating=np.array([2,1,2,1,2])
working=np.array([10,11,9,10,8])
playing=np.array([7,6,4,5,6])
y=np.vstack([sleeping,eating,working,playing])
labels=['Sleeping',"Eating",'Working',"Playing"]
colors=['#8c7ae6','#7f8fa6',"#273c75",'#dcdde1']
plt.stackplot(days,y,labels=labels,colors=colors)
plt.xlabel('Days')
plt.ylabel("Hours Spending")
plt.legend(loc='best')
plt.title('Activity Graph')
# Out:
# Text(0.5, 1.0, 'Activity Graph')

# %% [markdown]
# **Examples**

# %% [markdown]
# Make a bar graph that represents exotic pet ownership in the United States. There are 8,000,000 fish, 1,500,000 rabbits, 1,300,000 turtles, 1,000,000 poultry and 900,000 hamsters.

# %%
category=['fish','rabbits',"turtles",'poultry','hamsters']
owners=np.array([8000,1500,1300,1000,900])
plt.figure(figsize=[15,8])
plt.bar(category,owners)
plt.xlabel('Pets')
plt.ylabel('NO.of Owners')
plt.title('pet ownership in the United States')
plt.savefig('figure.png')
